# %% [markdown]
# # ***화승***

# %% [markdown]
# ## ***IMPORT LIBRARY***
# ---

# %%
### Library Import 
import os
import re
import sys
import glob
import shap
import optuna
import pickle
import warnings
import numpy as np 
import pandas as pd 
import seaborn as sns
import xgboost as xgb
from math import ceil
from tqdm import tqdm
from scipy import stats
import statsmodels.api as sm
from functools import partial
from collections import Counter
from pandarallel import pandarallel
from xgboost import XGBRegressor, callback as xgb_callback
from datetime import timedelta, time, datetime
from scipy.stats import truncnorm
from IPython.display import Image
from optbinning import OptimalBinning
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.font_manager as fm
import matplotlib.patches as patches
from matplotlib.dates import AutoDateLocator, AutoDateFormatter
warnings.filterwarnings('ignore')
plt.rc('font', family='Apple SD Gothic Neo')

# Pandas 옵션 설정 
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', None)

# Scikit-Learn 
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
from skopt import gp_minimize
from skopt.space import Integer, Real, Categorical
from skopt.utils import use_named_args
from skopt.plots import plot_convergence 

# Import fns 
from utils import * 
from hwaseung_fn import *

# %% [markdown]
# ## ***Load Dataset***
# ---

# %%
### Cluster Dict 
cluster_dict = {
        'cluster1': {'products': ["FFWED70284","FFWED70007","FFWED70267","FFWED70103","FFWED70199","FFSED70438","FFWED70033",
                                "FFWES60194","FFSED70498","FFSED70533","FFWED70321"],
                    'var': 'T5'},
        'cluster2': {'products': ["FFWED70019","FFWED70102","FFWED70283","FFHED70076","FFWED70338",
                                "FFHED70014","FFSED70032","FFHED70147",
                                "FFHED60009","FFHED60006"],
                    'var': 'T3'},
        'cluster3': {'products': ["HCSED50105", "HCSED60072",
                                "HCWED60031", "HCSED50391", "HCSED70092", "HCSED60024",],
                    'var': 'M/B 점도 (ML)'},
        'cluster4': {'products': ["HCSED60010", "HCSES60015", "HCWES60017",
                                "HCSED70584", "HCSED60530", "HCSED50047",
                                "HCSED40011", "HCSED20006",
                                "HCWED70019", "FCHED60002", "FCWED70009",
                                "HCSED60017", "HCSED70143"],
                    'var': 'M/B 점도 (MS)'}
        }

# Random Seed & Path 
random_seed = 22
path = '/Users/hwijongim/Library/CloudStorage/OneDrive-앰버로드/문서 - Solution/2502_화승/20.수행/22.분석과제/250408_분석_sm'

# Product 정의 
train_cluster = "cluster1"
p_codes = cluster_dict['cluster1']['products']  

# Target 
target_list = ["Ct 90"] + ["Scorch (T5)", "Scorch (T3)"] + ['Vm (T5)', "Vm (T3)", "M/B 점도 (ML)", "M/B 점도 (MS)"] + ["경도"]

# Data Import 
        # Log 
log_df = pd.read_csv(f"{path}/log_df_10s.csv")
# log_df = log_df[log_df["제품코드"].isin(cluster_dict[train_cluster]["products"])] 
        # QA 
qa_df = pd.read_csv(f"{path}/qa_df.csv") 
        # Recipe
recipe_df = pd.read_csv(f"{path}/recipe_df.csv") 
        # INFO 
info = pd.read_excel(f"{path}/투입자재 CODE별 비중 정보.xlsx", header=1, index_col=0).reset_index(drop=True)
        # Weather 
weather_df = pd.read_csv(f"{path}/weather_dg.csv")
weather_df["연월일"] = weather_df["연월일"].astype(str)

# Recipe Origin 
recipe_origin_df = recipe_df.copy()

# Print 
print('='*100)
print(f'Log Dataset: {log_df.shape}')
print(f'QA Dataset: {qa_df.shape}')
print(f'Recipe Dataset: {recipe_df.shape}')
print(f'INFO Dataset: {info.shape}')
print(f'Weather Dataset: {weather_df.shape}')
print('='*100)
# Out:
# ====================================================================================================
# Log Dataset: (9478081, 37)
# QA Dataset: (334291, 16)
# Recipe Dataset: (1813072, 13)
# INFO Dataset: (80, 2)
# Weather Dataset: (1268, 5)
# ====================================================================================================

# %% [markdown]
# ## ***Data Preprocessing***
# ---

# %%
### Log Dataset 정제 
log_df4, log_df5 = prep_log(log_df)

# Print 
print('='*100)
print(f'Log Dataset: {log_df4.shape}')
print(f'Log Train Dataset: {log_df5.shape}')
print('='*100)
# Out:
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=16145), Label(value='0 / 16145')))…
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.
# ====================================================================================================
# Log Dataset: (8566802, 39)
# Log Train Dataset: (128985, 18)
# ====================================================================================================

# %%
### QA Dataset 정제 
qa_df4, qa_df5 = prep_qa(qa_df, p_codes, target_list)

# Print 
print('='*100)
print(f'Qa Dataset: {qa_df4.shape}')
print(f'Qa Train Dataset: {qa_df5.shape}')
print('='*100)
# Out:
# ====================================================================================================
# Qa Dataset: (242922, 4)
# Qa Train Dataset: (137180, 14)
# ====================================================================================================

# %%
### Recipe Dataset 정제 
recipe_df = prep_recipe(recipe_origin_df, info) 

# Print 
print('='*100)
print(f'Recipe Dataset: {recipe_df.shape}')
print('='*100)
# Out:
# ====================================================================================================
# Recipe Dataset: (123200, 2)
# ====================================================================================================

# %%
### Concat Dataset 
df1 = pd.merge(left=log_df5, right=qa_df5, on="작업지시번호-배치", how="left")
df2 = pd.merge(left=df1, right=recipe_df, on="작업지시번호-배치", how="left")
df3 = pd.merge(left=df2, right=weather_df, on="연월일", how="left").drop(["연월일"], axis=1)    

# Print 
print('='*100)
print(f'Daset Shape: {df3.shape}')
print('='*100)
# Out:
# ====================================================================================================
# Daset Shape: (128985, 35)
# ====================================================================================================

# %%
### Get Cluster Column 
cluster = 3
dataset = create_cluster_col(df3, p_type='FMB')  
dataset = dataset[dataset['Cluster']==cluster].reset_index(drop=True)

# Print 
print('='*100)
print(f'Train Dataset Shape: {dataset.shape}')
print('='*100)
# Out:
# ====================================================================================================
# Train Dataset Shape: (4214, 36)
# ====================================================================================================

# %%
### Target Value 확인 
# 확인할 컬럼 리스트
target_lst = [
    "cycle time", "Ct 90_결과", "M/B_결과", "M/B_기준",
     "Scorch_결과", "Vm_결과", "경도_결과"
]

# Print 
print('='*100)
print(dataset[target_lst].count())
print('='*100)
# Out:
# ====================================================================================================
# cycle time    4192
# Ct 90_결과      4214
# M/B_결과           0
# M/B_기준           0
# Scorch_결과        2
# Vm_결과         1350
# 경도_결과          346
# dtype: int64
# ====================================================================================================

# %% [markdown]
# ## ***MODELLING***
# ---

# %%
### Train Test Split 
# Targets 
targets = ['cycle time','Ct 90_결과','Vm_결과','경도_결과']

# Cycle Time 
cycle_train_dataset, cycle_test_dataset, cycle_scaler, cycle_scaler_cols = create_train_test_dataset(dataset, targets[0], p_type='FMB')

# CT90 
ct_train_dataset, ct_test_dataset, ct_scaler, ct_scaler_cols = create_train_test_dataset(dataset, targets[1], p_type='FMB')

# Vm 
vm_train_dataset, vm_test_dataset, vm_scaler, vm_scaler_cols = create_train_test_dataset(dataset, targets[2], p_type='FMB')

# Hard 
hard_train_dataset, hard_test_dataset, hard_scaler, hard_scaler_cols = create_train_test_dataset(dataset, targets[3], p_type='FMB')

# Print 
print('='*100)
print(f"{'cycle time':<21} | {len(cycle_train_dataset):>14,} | {len(cycle_test_dataset):>13,}")
print(f"{'Ct 90_결과':<20} | {len(ct_train_dataset):>14,} | {len(ct_test_dataset):>13,}")
print(f"{'Vm (T3)_결과':<20} | {len(vm_train_dataset):>14,} | {len(vm_test_dataset):>13,}")
print(f"{'경도_결과':<19} | {len(hard_train_dataset):>14,} | {len(hard_test_dataset):>13,}") 
print("="*100)
# Out:
# ====================================================================================================
# cycle time            |            495 |           117
# Ct 90_결과             |            495 |           117
# Vm (T3)_결과           |            495 |           117
# 경도_결과               |             19 |             5
# ====================================================================================================

# %%
### Modelling 
# Cycle Time 
cycle_model, cycle_importance = train_tree(cycle_train_dataset, cycle_test_dataset, target_col='cycle time')

# CT90 
ct_model, ct_importance = train_tree(ct_train_dataset, ct_test_dataset, target_col='Ct 90_결과')

# Vm 
vm_model, vm_importance = train_tree(vm_train_dataset, vm_test_dataset, target_col='Vm_결과')

# Hard 
hard_model, hard_importance = train_tree(hard_train_dataset, hard_test_dataset, target_col='경도_결과')
# Out:
# [I 2025-10-27 18:19:16,919] A new study created in memory with name: no-name-f9138925-b5a4-407e-96e2-078bc0bcfa5e
# 학습할 Tree Features: 20 | ['step1_Ram 압력', 'step2_Ram 압력', 'step3_Ram 압력', 'step1_Rotor speed', 'step2_Rotor speed', 'step3_Rotor speed', 'step1_mix온도', 'step2_mix온도', 'step3_mix온도', 'step1_전력량', 'step2_전력량', 'step3_전력량', 'step1_time', 'step2_time', 'step3_time', '필팩터', 'TA_AVG', 'TA_MAX', 'TA_MIN', 'Vm_feature']
# 학습 Tree 데이터 수: 495
#   0%|          | 0/10 [00:00<?, ?it/s]
# [I 2025-10-27 18:19:33,884] Trial 0 finished with value: 7.760978999354709 and parameters: {'n_estimators': 1947, 'max_depth': 11, 'learning_rate': 0.0035445876566373978, 'subsample': 0.7528479482441048, 'gamma': 0.403465478516803, 'reg_lambda': 0.003578040981700896}. Best is trial 0 with value: 7.760978999354709.
# [I 2025-10-27 18:19:48,249] Trial 1 finished with value: 7.053332065415494 and parameters: {'n_estimators': 1702, 'max_depth': 7, 'learning_rate': 0.0035611784217285582, 'subsample': 0.7823494616269389, 'gamma': 0.07765523728409807, 'reg_lambda': 1.68487981716871}. Best is trial 1 with value: 7.053332065415494.
# [I 2025-10-27 18:20:06,848] Trial 2 finished with value: 7.094862648789516 and parameters: {'n_estimators': 1846, 'max_depth': 12, 'learning_rate': 0.0039807615524625846, 'subsample': 0.8231058196250728, 'gamma': 0.2709047082505202, 'reg_lambda': 0.5168054029216645}. Best is trial 1 with value: 7.053332065415494.
# [I 2025-10-27 18:20:23,377] Trial 3 finished with value: 8.898481319116028 and parameters: {'n_estimators': 1254, 'max_depth': 12, 'learning_rate': 0.0021395791932215785, 'subsample': 0.8484590684481379, 'gamma': 0.3780881457542619, 'reg_lambda': 0.0025888671028255483}. Best is trial 1 with value: 7.053332065415494.
# [I 2025-10-27 18:20:52,631] Trial 4 finished with value: 8.654641230318177 and parameters: {'n_estimators': 2858, 'max_depth': 7, 'learning_rate': 0.0010481891755057496, 'subsample': 0.897605395965251, 'gamma': 0.47561123935180166, 'reg_lambda': 0.20988285964765482}. Best is trial 1 with value: 7.053332065415494.
# [I 2025-10-27 18:21:10,718] Trial 5 finished with value: 6.647684036755961 and parameters: {'n_estimators': 1302, 'max_depth': 10, 'learning_rate': 0.008113744457659324, 'subsample': 0.8143176252323973, 'gamma': 0.3190147145272485, 'reg_lambda': 2.560837185902061}. Best is trial 5 with value: 6.647684036755961.
# [I 2025-10-27 18:21:27,562] Trial 6 finished with value: 8.254185665373228 and parameters: {'n_estimators': 1908, 'max_depth': 10, 'learning_rate': 0.006136559366738713, 'subsample': 0.9283349744659244, 'gamma': 0.464435965883874, 'reg_lambda': 0.06939045376832553}. Best is trial 5 with value: 6.647684036755961.
# [I 2025-10-27 18:21:29,166] Trial 7 finished with value: 8.243755242754256 and parameters: {'n_estimators': 486, 'max_depth': 10, 'learning_rate': 0.2656070392408074, 'subsample': 0.9012238717414928, 'gamma': 0.015688262602853553, 'reg_lambda': 0.07586850131513577}. Best is trial 5 with value: 6.647684036755961.
# [I 2025-10-27 18:21:36,796] Trial 8 finished with value: 7.432428012612053 and parameters: {'n_estimators': 2809, 'max_depth': 8, 'learning_rate': 0.08302318984903727, 'subsample': 0.7516648303995015, 'gamma': 0.23778436575595713, 'reg_lambda': 0.251348289640533}. Best is trial 5 with value: 6.647684036755961.
# [I 2025-10-27 18:21:41,963] Trial 9 finished with value: 7.323066863986419 and parameters: {'n_estimators': 1798, 'max_depth': 8, 'learning_rate': 0.17663815725897042, 'subsample': 0.9075504155484508, 'gamma': 0.2418722370490743, 'reg_lambda': 0.46420723678946263}. Best is trial 5 with value: 6.647684036755961.
# Tree 1차 모델 평가: R2: 0.975 | sMAPE: 0.889
# [I 2025-10-27 18:21:47,503] A new study created in memory with name: no-name-a617dec4-549a-4631-b777-90ac191c155f
# ====================================================================================================
# Train Accuracy
# Train RMSE : 0.669
# Train R2   : 1.000
# Train SMAPE : 0.11
# ----------------------------------------------------------------------------------------------------
# Test Accuracy
# Test RMSE : 4.461
# Test R2   : 0.975
# Test SMAPE : 0.89
# ====================================================================================================
# 학습할 Tree Features: 20 | ['step1_Ram 압력', 'step2_Ram 압력', 'step3_Ram 압력', 'step1_Rotor speed', 'step2_Rotor speed', 'step3_Rotor speed', 'step1_mix온도', 'step2_mix온도', 'step3_mix온도', 'step1_전력량', 'step2_전력량', 'step3_전력량', 'step1_time', 'step2_time', 'step3_time', '필팩터', 'TA_AVG', 'TA_MAX', 'TA_MIN', 'Vm_feature']
# 학습 Tree 데이터 수: 495
#   0%|          | 0/10 [00:00<?, ?it/s]
# [I 2025-10-27 18:21:53,218] Trial 0 finished with value: 6.541191917334207 and parameters: {'n_estimators': 873, 'max_depth': 7, 'learning_rate': 0.02113752193322544, 'subsample': 0.7072662226635528, 'gamma': 0.11637151765523035, 'reg_lambda': 0.0014817944927814077}. Best is trial 0 with value: 6.541191917334207.
# [I 2025-10-27 18:21:58,265] Trial 1 finished with value: 8.19202833748025 and parameters: {'n_estimators': 360, 'max_depth': 9, 'learning_rate': 0.0021310788436467634, 'subsample': 0.8999667731173415, 'gamma': 0.010447257272164112, 'reg_lambda': 0.014900056559487635}. Best is trial 0 with value: 6.541191917334207.
# [I 2025-10-27 18:22:28,528] Trial 2 finished with value: 6.940032579408929 and parameters: {'n_estimators': 1982, 'max_depth': 11, 'learning_rate': 0.001377260169030709, 'subsample': 0.8380316010363356, 'gamma': 0.03191992303232083, 'reg_lambda': 0.15378017597816235}. Best is trial 0 with value: 6.541191917334207.
# [I 2025-10-27 18:22:37,712] Trial 3 finished with value: 6.673580698054141 and parameters: {'n_estimators': 788, 'max_depth': 8, 'learning_rate': 0.008452538719574288, 'subsample': 0.7580612651580877, 'gamma': 0.44387757316733245, 'reg_lambda': 1.8322376447098159}. Best is trial 0 with value: 6.541191917334207.
# [I 2025-10-27 18:22:42,921] Trial 4 finished with value: 7.259993188493914 and parameters: {'n_estimators': 2176, 'max_depth': 6, 'learning_rate': 0.26457763976536064, 'subsample': 0.8677406715289088, 'gamma': 0.07944861685522708, 'reg_lambda': 0.004897171825736357}. Best is trial 0 with value: 6.541191917334207.
# [I 2025-10-27 18:23:22,137] Trial 5 finished with value: 6.589539409550665 and parameters: {'n_estimators': 2399, 'max_depth': 12, 'learning_rate': 0.00193900838202687, 'subsample': 0.7622800209590413, 'gamma': 0.049434711744133886, 'reg_lambda': 0.5627183881472557}. Best is trial 0 with value: 6.541191917334207.
# [I 2025-10-27 18:23:26,123] Trial 6 finished with value: 8.03215913219115 and parameters: {'n_estimators': 333, 'max_depth': 9, 'learning_rate': 0.0025583131506755966, 'subsample': 0.9107163314290562, 'gamma': 0.2295458263325577, 'reg_lambda': 0.0029041218697818433}. Best is trial 0 with value: 6.541191917334207.
# [I 2025-10-27 18:23:36,945] Trial 7 finished with value: 6.968688838431452 and parameters: {'n_estimators': 2688, 'max_depth': 12, 'learning_rate': 0.010980433017282026, 'subsample': 0.8445103820367019, 'gamma': 0.3383561349058492, 'reg_lambda': 0.02839627375176017}. Best is trial 0 with value: 6.541191917334207.
# [I 2025-10-27 18:23:44,285] Trial 8 finished with value: 6.754956057228952 and parameters: {'n_estimators': 2217, 'max_depth': 9, 'learning_rate': 0.04696090331021286, 'subsample': 0.7250421132790059, 'gamma': 0.1705920273299294, 'reg_lambda': 2.633305495471014}. Best is trial 0 with value: 6.541191917334207.
# [I 2025-10-27 18:23:58,818] Trial 9 finished with value: 6.5724763535286215 and parameters: {'n_estimators': 2014, 'max_depth': 6, 'learning_rate': 0.0019995472560771616, 'subsample': 0.8402041419711471, 'gamma': 0.01663855534746017, 'reg_lambda': 0.5435366078372799}. Best is trial 0 with value: 6.541191917334207.
# Tree 1차 모델 평가: R2: 0.723 | sMAPE: 1.547
# [I 2025-10-27 18:24:00,755] A new study created in memory with name: no-name-a8efc93d-f3bf-499f-8a46-fed7d19d8a7d
# ====================================================================================================
# Train Accuracy
# Train RMSE : 0.171
# Train R2   : 1.000
# Train SMAPE : 0.05
# ----------------------------------------------------------------------------------------------------
# Test Accuracy
# Test RMSE : 5.385
# Test R2   : 0.723
# Test SMAPE : 1.55
# ====================================================================================================
# 학습할 Tree Features: 20 | ['step1_Ram 압력', 'step2_Ram 압력', 'step3_Ram 압력', 'step1_Rotor speed', 'step2_Rotor speed', 'step3_Rotor speed', 'step1_mix온도', 'step2_mix온도', 'step3_mix온도', 'step1_전력량', 'step2_전력량', 'step3_전력량', 'step1_time', 'step2_time', 'step3_time', '필팩터', 'TA_AVG', 'TA_MAX', 'TA_MIN', 'Vm_feature']
# 학습 Tree 데이터 수: 495
#   0%|          | 0/10 [00:00<?, ?it/s]
# [I 2025-10-27 18:24:09,568] Trial 0 finished with value: 2.4807114672818398 and parameters: {'n_estimators': 736, 'max_depth': 9, 'learning_rate': 0.001095508550304932, 'subsample': 0.9151602847819086, 'gamma': 0.37506958905346566, 'reg_lambda': 0.001023948694643888}. Best is trial 0 with value: 2.4807114672818398.
# [I 2025-10-27 18:24:25,336] Trial 1 finished with value: 2.044263090124552 and parameters: {'n_estimators': 2673, 'max_depth': 7, 'learning_rate': 0.0030339936532737624, 'subsample': 0.9353258331510567, 'gamma': 0.28460952437236214, 'reg_lambda': 0.002662819076187203}. Best is trial 1 with value: 2.044263090124552.
# [I 2025-10-27 18:24:50,929] Trial 2 finished with value: 1.986396163040818 and parameters: {'n_estimators': 1904, 'max_depth': 11, 'learning_rate': 0.0014302480352444517, 'subsample': 0.770270721208388, 'gamma': 0.09707061717050453, 'reg_lambda': 0.29742899669184425}. Best is trial 2 with value: 1.986396163040818.
# [I 2025-10-27 18:24:56,962] Trial 3 finished with value: 1.9762075419162886 and parameters: {'n_estimators': 2299, 'max_depth': 10, 'learning_rate': 0.0690446534028975, 'subsample': 0.7753224857750426, 'gamma': 0.023467768257096344, 'reg_lambda': 0.020024741972249585}. Best is trial 3 with value: 1.9762075419162886.
# [I 2025-10-27 18:25:09,683] Trial 4 finished with value: 1.9697581968389748 and parameters: {'n_estimators': 2936, 'max_depth': 7, 'learning_rate': 0.004875800831583973, 'subsample': 0.830706237647793, 'gamma': 0.41304634044694083, 'reg_lambda': 0.23752045948054862}. Best is trial 4 with value: 1.9697581968389748.
# [I 2025-10-27 18:25:14,325] Trial 5 finished with value: 2.0826351240862055 and parameters: {'n_estimators': 1527, 'max_depth': 12, 'learning_rate': 0.02303233340564901, 'subsample': 0.9051183124803627, 'gamma': 0.3879375978023239, 'reg_lambda': 0.003725632230289234}. Best is trial 4 with value: 1.9697581968389748.
# [I 2025-10-27 18:25:17,254] Trial 6 finished with value: 1.938852851471114 and parameters: {'n_estimators': 903, 'max_depth': 11, 'learning_rate': 0.04228327786697347, 'subsample': 0.772327352838339, 'gamma': 0.40878586580419446, 'reg_lambda': 0.0017158953584467491}. Best is trial 6 with value: 1.938852851471114.
# [I 2025-10-27 18:25:22,464] Trial 7 finished with value: 2.004549077056826 and parameters: {'n_estimators': 2457, 'max_depth': 9, 'learning_rate': 0.12379744315367096, 'subsample': 0.770992555900381, 'gamma': 0.22607198226165076, 'reg_lambda': 0.0395579002103532}. Best is trial 6 with value: 1.938852851471114.
# [I 2025-10-27 18:25:29,999] Trial 8 finished with value: 1.9266330546533823 and parameters: {'n_estimators': 2097, 'max_depth': 12, 'learning_rate': 0.018920723517669245, 'subsample': 0.7142647635864999, 'gamma': 0.34092116558929275, 'reg_lambda': 1.0141533691593188}. Best is trial 8 with value: 1.9266330546533823.
# [I 2025-10-27 18:25:38,405] Trial 9 finished with value: 2.0346317516405525 and parameters: {'n_estimators': 1032, 'max_depth': 6, 'learning_rate': 0.0044447924632587815, 'subsample': 0.9516909328340553, 'gamma': 0.31966374389530794, 'reg_lambda': 0.512053065748505}. Best is trial 8 with value: 1.9266330546533823.
# Tree 1차 모델 평가: R2: 0.731 | sMAPE: 2.12
# [I 2025-10-27 18:25:40,942] A new study created in memory with name: no-name-da49668f-7355-4889-9feb-a1f35e7a80c1
# ====================================================================================================
# Train Accuracy
# Train RMSE : 0.253
# Train R2   : 0.996
# Train SMAPE : 0.29
# ----------------------------------------------------------------------------------------------------
# Test Accuracy
# Test RMSE : 1.885
# Test R2   : 0.731
# Test SMAPE : 2.12
# ====================================================================================================
# 학습할 Tree Features: 20 | ['step1_Ram 압력', 'step2_Ram 압력', 'step3_Ram 압력', 'step1_Rotor speed', 'step2_Rotor speed', 'step3_Rotor speed', 'step1_mix온도', 'step2_mix온도', 'step3_mix온도', 'step1_전력량', 'step2_전력량', 'step3_전력량', 'step1_time', 'step2_time', 'step3_time', '필팩터', 'TA_AVG', 'TA_MAX', 'TA_MIN', 'Vm_feature']
# 학습 Tree 데이터 수: 19
#   0%|          | 0/10 [00:00<?, ?it/s]
# [I 2025-10-27 18:25:43,704] Trial 0 finished with value: 2.2913827449393853 and parameters: {'n_estimators': 1404, 'max_depth': 11, 'learning_rate': 0.14046023451767864, 'subsample': 0.8074865706569253, 'gamma': 0.16869870940518222, 'reg_lambda': 0.01036656043147847}. Best is trial 0 with value: 2.2913827449393853.
# [I 2025-10-27 18:25:45,494] Trial 1 finished with value: 2.265768351634214 and parameters: {'n_estimators': 707, 'max_depth': 7, 'learning_rate': 0.013508347133671593, 'subsample': 0.748669452501145, 'gamma': 0.30899055601374, 'reg_lambda': 0.07718258016598709}. Best is trial 1 with value: 2.265768351634214.
# [I 2025-10-27 18:25:53,203] Trial 2 finished with value: 2.3489474990643013 and parameters: {'n_estimators': 2940, 'max_depth': 10, 'learning_rate': 0.0033873774241544572, 'subsample': 0.9094907688252476, 'gamma': 0.17034458035336164, 'reg_lambda': 0.0015217552528290575}. Best is trial 1 with value: 2.265768351634214.
# [I 2025-10-27 18:25:57,274] Trial 3 finished with value: 2.3391630138168167 and parameters: {'n_estimators': 2218, 'max_depth': 8, 'learning_rate': 0.08795172176299648, 'subsample': 0.9016236935678752, 'gamma': 0.37923971381861077, 'reg_lambda': 0.22359206553149275}. Best is trial 1 with value: 2.265768351634214.
# [I 2025-10-27 18:25:58,102] Trial 4 finished with value: 2.319418055960748 and parameters: {'n_estimators': 370, 'max_depth': 12, 'learning_rate': 0.0843829133369551, 'subsample': 0.9116689636548425, 'gamma': 0.15201532006261376, 'reg_lambda': 1.0054179612715246}. Best is trial 1 with value: 2.265768351634214.
# [I 2025-10-27 18:26:04,082] Trial 5 finished with value: 2.202729197142747 and parameters: {'n_estimators': 2781, 'max_depth': 8, 'learning_rate': 0.009469957194533989, 'subsample': 0.9793879346916337, 'gamma': 0.40721724592604763, 'reg_lambda': 0.2246045842849579}. Best is trial 5 with value: 2.202729197142747.
# [I 2025-10-27 18:26:10,870] Trial 6 finished with value: 2.4046935168208683 and parameters: {'n_estimators': 2887, 'max_depth': 7, 'learning_rate': 0.006577154757908548, 'subsample': 0.7419649562426723, 'gamma': 0.08188572397599914, 'reg_lambda': 0.0014844338595037382}. Best is trial 5 with value: 2.202729197142747.
# [I 2025-10-27 18:26:19,480] Trial 7 finished with value: 2.076058419315236 and parameters: {'n_estimators': 1947, 'max_depth': 8, 'learning_rate': 0.0010669005619101158, 'subsample': 0.8850457126609412, 'gamma': 0.2323120617496976, 'reg_lambda': 2.8260244277468978}. Best is trial 7 with value: 2.076058419315236.
# [I 2025-10-27 18:26:23,022] Trial 8 finished with value: 2.5342282985337943 and parameters: {'n_estimators': 1729, 'max_depth': 6, 'learning_rate': 0.23420941020705538, 'subsample': 0.9732226378784572, 'gamma': 0.2580028024994207, 'reg_lambda': 0.030827392643527744}. Best is trial 7 with value: 2.076058419315236.
# [I 2025-10-27 18:26:31,007] Trial 9 finished with value: 2.19696569800297 and parameters: {'n_estimators': 2223, 'max_depth': 9, 'learning_rate': 0.003271419567502429, 'subsample': 0.9962738237358547, 'gamma': 0.11294280435321113, 'reg_lambda': 0.9708475956532064}. Best is trial 7 with value: 2.076058419315236.
# Tree 1차 모델 평가: R2: -0.267 | sMAPE: 2.022
# ====================================================================================================
# Train Accuracy
# Train RMSE : 0.734
# Train R2   : 0.788
# Train SMAPE : 0.72
# ----------------------------------------------------------------------------------------------------
# Test Accuracy
# Test RMSE : 1.859
# Test R2   : -0.267
# Test SMAPE : 2.02
# ====================================================================================================
