# %% [markdown]
# # ***화승***

# %% [markdown]
# ## ***IMPORT LIBRARY***
# ---

# %%
### Library Import 
import os
import re
import sys
import glob
import shap
import optuna
import pickle
import warnings
import numpy as np 
import pandas as pd 
import seaborn as sns
import xgboost as xgb
from math import ceil
from tqdm import tqdm
from scipy import stats
import statsmodels.api as sm
from functools import partial
from collections import Counter
from pandarallel import pandarallel
from xgboost import XGBRegressor, callback as xgb_callback
from datetime import timedelta, time, datetime
from scipy.stats import truncnorm
from IPython.display import Image
from optbinning import OptimalBinning
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.font_manager as fm
import matplotlib.patches as patches
from matplotlib.dates import AutoDateLocator, AutoDateFormatter
warnings.filterwarnings('ignore')
plt.rc('font', family='Apple SD Gothic Neo')

# Pandas 옵션 설정 
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', None)

# Scikit-Learn 
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
from skopt import gp_minimize
from skopt.space import Integer, Real, Categorical
from skopt.utils import use_named_args
from skopt.plots import plot_convergence 
from sklearn.linear_model import ElasticNetCV
from sklearn.pipeline import make_pipeline

# Import fns 
from utils import * 
from hwaseung_fn import *

# %%
### Parameters 
path = '/Users/hwijongim/Library/CloudStorage/OneDrive-앰버로드/문서 - Solution/2502_화승/20.수행/22.분석과제/250408_분석_sm'
p_type = 'FMB'

# %% [markdown]
# ## ***Load Dataset***
# ---

# %%
### Load Raw Data 
# Data Import 
log_df, qa_df, recipe_df, info, weather_df = import_raw_data(path) 
recipe_origin_df = recipe_df.copy() 

# Print 
print('='*100)
print(f'Log Dataset: {log_df.shape}')
print(f'QA Dataset: {qa_df.shape}')
print(f'Recipe Dataset: {recipe_df.shape}')
print(f'INFO Dataset: {info.shape}')
print(f'Weather Dataset: {weather_df.shape}')
print('='*100)
# Out:
# ====================================================================================================
# Log Dataset: (9478081, 37)
# QA Dataset: (334291, 16)
# Recipe Dataset: (1813072, 13)
# INFO Dataset: (80, 2)
# Weather Dataset: (1268, 5)
# ====================================================================================================

# %% [markdown]
# ## ***Data Preprocessing***
# ---

# %%
### Log Dataset 정제 
log_df4, log_df5 = prep_log(log_df)

# Print 
print('='*100)
print(f'Log Dataset: {log_df4.shape}')
print(f'Log Train Dataset: {log_df5.shape}')
print('='*100)
# Out:
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=16145), Label(value='0 / 16145')))…
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.
# ====================================================================================================
# Log Dataset: (8566802, 39)
# Log Train Dataset: (128985, 18)
# ====================================================================================================

# %%
### QA Dataset 정제 
qa_df4, qa_df5 = prep_qa(qa_df)

# Print 
print('='*100)
print(f'Qa Dataset: {qa_df4.shape}')
print(f'Qa Train Dataset: {qa_df5.shape}')
print('='*100)
# Out:
# ====================================================================================================
# Qa Dataset: (242922, 4)
# Qa Train Dataset: (137180, 14)
# ====================================================================================================

# %%
### Recipe Dataset 정제 
recipe_df = prep_recipe(recipe_origin_df, info) 

# Print 
print('='*100)
print(f'Recipe Dataset: {recipe_df.shape}')
print('='*100)
# Out:
# ====================================================================================================
# Recipe Dataset: (123200, 2)
# ====================================================================================================

# %%
### Concat Dataset 
df1 = pd.merge(left=log_df5, right=qa_df5, on="작업지시번호-배치", how="left")
df2 = pd.merge(left=df1, right=recipe_df, on="작업지시번호-배치", how="left")
df3 = pd.merge(left=df2, right=weather_df, on="연월일", how="left").drop(["연월일"], axis=1)    

# Print 
print('='*100)
print(f'Daset Shape: {df3.shape}')
print('='*100)
# Out:
# ====================================================================================================
# Daset Shape: (128985, 35)
# ====================================================================================================

# %%
### Get Cluster Column 
dataset = create_cluster_col(df3, p_type)  

# Print 
print('='*100)
print(f'Train Dataset Shape: {dataset.shape}')
print('='*100)
# Out:
# ====================================================================================================
# Train Dataset Shape: (101787, 36)
# ====================================================================================================

# %%
### Target Value 확인 
# 확인할 컬럼 리스트
target_lst = [
    "cycle time", "Ct 90_결과", "M/B_결과", "M/B_기준",
    "Scorch_결과", "Vm_결과", "경도_결과"
]

# Print 
print('='*100)
print(dataset[target_lst].count())
print('='*100)
# Out:
# ====================================================================================================
# cycle time    101440
# Ct 90_결과       59336
# M/B_결과             0
# M/B_기준             0
# Scorch_결과      15154
# Vm_결과          39284
# 경도_결과          69844
# dtype: int64
# ====================================================================================================

# %% [markdown]
# ## ***MODELLING***
# ---

# %%
### Train Test Split 
# Targets 
targets = ['cycle time','Ct 90_결과','Scorch_결과','Vm_결과','경도_결과']

# Cycle Time 
cycle_train_dataset, cycle_test_dataset, cycle_scaler, cycle_scaler_cols = create_train_test_dataset(dataset, targets[0], p_type)

# CT90 
ct_train_dataset, ct_test_dataset, ct_scaler, ct_scaler_cols = create_train_test_dataset(dataset, targets[1], p_type)

# Scorch
sc_train_dataset, sc_test_dataset, sc_scaler, sc_scaler_cols = create_train_test_dataset(dataset, targets[2], p_type)

# Vm 
vm_train_dataset, vm_test_dataset, vm_scaler, vm_scaler_cols = create_train_test_dataset(dataset, targets[3], p_type)

# Hard 
hard_train_dataset, hard_test_dataset, hard_scaler, hard_scaler_cols = create_train_test_dataset(dataset, targets[4], p_type)

# Print 
print('='*100)
print(f"{'cycle time':<21} | {len(cycle_train_dataset):>14,} | {len(cycle_test_dataset):>13,}")
print(f"{'Ct 90_결과':<20} | {len(ct_train_dataset):>14,} | {len(ct_test_dataset):>13,}")
print(f"{'Scorch_결과':<20} | {len(sc_train_dataset):>14,} | {len(sc_test_dataset):>13,}")
print(f"{'Vm_결과':<20} | {len(vm_train_dataset):>14,} | {len(vm_test_dataset):>13,}")
print(f"{'경도_결과':<19} | {len(hard_train_dataset):>14,} | {len(hard_test_dataset):>13,}") 
print("="*100)
# Out:
# ====================================================================================================
# cycle time            |          9,851 |         2,311
# Ct 90_결과             |          4,713 |         1,106
# Scorch_결과            |          9,851 |         2,311
# Vm_결과                |          9,851 |         2,311
# 경도_결과               |          5,849 |         1,372
# ====================================================================================================

# %%
### Modelling - Lienar 
# Cycle Time 
cycle_model, cycle_importance = train_linear(cycle_train_dataset, cycle_test_dataset, target_col='cycle time')

# CT90 
ct_model, ct_importance = train_linear(ct_train_dataset, ct_test_dataset, target_col='Ct 90_결과')

# Scorch 
sc_model, sc_importance = train_linear(sc_train_dataset, sc_test_dataset, target_col='Scorch_결과')

# Vm 
vm_model, vm_importance = train_linear(vm_train_dataset, vm_test_dataset, target_col='Vm_결과')

# Hard 
hard_model, hard_importance = train_linear(hard_train_dataset, hard_test_dataset, target_col='경도_결과')
# Out:
# Linear Model 학습 시작, Features => Index(['const', 'step1_Ram 압력', 'step2_Ram 압력', 'step3_Ram 압력',
#        'step1_Rotor speed', 'step2_Rotor speed', 'step3_Rotor speed',
#        'step1_mix온도', 'step2_mix온도', 'step3_mix온도', 'step1_전력량', 'step2_전력량',
#        'step3_전력량', 'step1_time', 'step2_time', 'step3_time', '필팩터', 'TA_AVG',
#        'TA_MAX', 'TA_MIN'],
#       dtype='object') | Target => cycle time
# Model 평가: R2 = 1.0 | sMAPE = 2.8191345263392046e-13
# ====================================================================================================
# Train Accuracy
# Train RMSE : 0.000
# Train R2   : 1.000
# Train SMAPE : 0.00
# ----------------------------------------------------------------------------------------------------
# Test Accuracy
# Test RMSE : 0.000
# Test R2   : 1.000
# Test SMAPE : 0.00
# ====================================================================================================
# Linear Model 학습 시작, Features => Index(['const', 'step1_Ram 압력', 'step2_Ram 압력', 'step3_Ram 압력',
#        'step1_Rotor speed', 'step2_Rotor speed', 'step3_Rotor speed',
#        'step1_mix온도', 'step2_mix온도', 'step3_mix온도', 'step1_전력량', 'step2_전력량',
#        'step3_전력량', 'step1_time', 'step2_time', 'step3_time', '필팩터', 'TA_AVG',
#        'TA_MAX', 'TA_MIN'],
#       dtype='object') | Target => Ct 90_결과
# Model 평가: R2 = 0.46196721092370674 | sMAPE = 8.800100464168626
# ====================================================================================================
# Train Accuracy
# Train RMSE : 22.223
# Train R2   : 0.425
# Train SMAPE : 9.13
# ----------------------------------------------------------------------------------------------------
# Test Accuracy
# Test RMSE : 21.192
# Test R2   : 0.462
# Test SMAPE : 8.80
# ====================================================================================================
# Linear Model 학습 시작, Features => Index(['const', 'step1_Ram 압력', 'step2_Ram 압력', 'step3_Ram 압력',
#        'step1_Rotor speed', 'step2_Rotor speed', 'step3_Rotor speed',
#        'step1_mix온도', 'step2_mix온도', 'step3_mix온도', 'step1_전력량', 'step2_전력량',
#        'step3_전력량', 'step1_time', 'step2_time', 'step3_time', '필팩터', 'TA_AVG',
#        'TA_MAX', 'TA_MIN'],
#       dtype='object') | Target => Scorch_결과
# Model 평가: R2 = 0.3457894972711466 | sMAPE = 9.771576711738676
# ====================================================================================================
# Train Accuracy
# Train RMSE : 70.627
# Train R2   : 0.331
# Train SMAPE : 9.95
# ----------------------------------------------------------------------------------------------------
# Test Accuracy
# Test RMSE : 68.801
# Test R2   : 0.346
# Test SMAPE : 9.77
# ====================================================================================================
# Linear Model 학습 시작, Features => Index(['const', 'step1_Ram 압력', 'step2_Ram 압력', 'step3_Ram 압력',
#        'step1_Rotor speed', 'step2_Rotor speed', 'step3_Rotor speed',
#        'step1_mix온도', 'step2_mix온도', 'step3_mix온도', 'step1_전력량', 'step2_전력량',
#        'step3_전력량', 'step1_time', 'step2_time', 'step3_time', '필팩터', 'TA_AVG',
#        'TA_MAX', 'TA_MIN'],
#       dtype='object') | Target => Vm_결과
# Model 평가: R2 = 0.38139185679741194 | sMAPE = 5.673912293565612
# ====================================================================================================
# Train Accuracy
# Train RMSE : 3.568
# Train R2   : 0.351
# Train SMAPE : 5.62
# ----------------------------------------------------------------------------------------------------
# Test Accuracy
# Test RMSE : 3.648
# Test R2   : 0.381
# Test SMAPE : 5.67
# ====================================================================================================
# Linear Model 학습 시작, Features => Index(['const', 'step1_Ram 압력', 'step2_Ram 압력', 'step3_Ram 압력',
#        'step1_Rotor speed', 'step2_Rotor speed', 'step3_Rotor speed',
#        'step1_mix온도', 'step2_mix온도', 'step3_mix온도', 'step1_전력량', 'step2_전력량',
#        'step3_전력량', 'step1_time', 'step2_time', 'step3_time', '필팩터', 'TA_AVG',
#        'TA_MAX', 'TA_MIN'],
#       dtype='object') | Target => 경도_결과
# Model 평가: R2 = 0.4386237127995112 | sMAPE = 1.9957296980450439
# ====================================================================================================
# Train Accuracy
# Train RMSE : 2.022
# Train R2   : 0.434
# Train SMAPE : 1.99
# ----------------------------------------------------------------------------------------------------
# Test Accuracy
# Test RMSE : 2.056
# Test R2   : 0.439
# Test SMAPE : 2.00
# ====================================================================================================

# %%
### Print Feature Importance 
print('='*100)
print(f'Cycle Time: {cycle_importance}')
print('-'*100)
print(f'CT90: {ct_importance}')
print('-'*100)
print(f'Scorch: {sc_importance}')
print('-'*100)
print(f'Vm: {vm_importance}')
print('-'*100)
print(f'Hardness: {hard_importance}')
print('='*100)
# Out:
# ====================================================================================================
# Cycle Time: ['step3_mix온도', 'step1_time', 'step2_time', 'step3_time']
# ----------------------------------------------------------------------------------------------------
# CT90: ['step2_Ram 압력', 'step1_Rotor speed', 'step2_Rotor speed', 'step3_Rotor speed', 'step1_mix온도', 'step2_mix온도', 'step3_mix온도', 'step1_전력량', 'step2_전력량', 'step3_전력량', 'step1_time', 'step2_time', 'step3_time', '필팩터', 'TA_MAX']
# ----------------------------------------------------------------------------------------------------
# Scorch: ['step1_Ram 압력', 'step3_Ram 압력', 'step1_Rotor speed', 'step2_Rotor speed', 'step3_Rotor speed', 'step1_mix온도', 'step2_mix온도', 'step1_전력량', 'step1_time', 'step2_time', '필팩터', 'TA_MIN']
# ----------------------------------------------------------------------------------------------------
# Vm: ['step1_Ram 압력', 'step2_Ram 압력', 'step3_Ram 압력', 'step1_Rotor speed', 'step2_Rotor speed', 'step3_Rotor speed', 'step1_mix온도', 'step2_mix온도', 'step3_mix온도', 'step1_전력량', 'step2_전력량', 'step3_전력량', 'step1_time', 'step2_time', 'step3_time', '필팩터', 'TA_AVG', 'TA_MIN']
# ----------------------------------------------------------------------------------------------------
# Hardness: ['step3_Ram 압력', 'step1_Rotor speed', 'step2_Rotor speed', 'step3_Rotor speed', 'step1_mix온도', 'step2_mix온도', 'step3_mix온도', 'step2_전력량', 'step3_전력량', 'step2_time', 'step3_time', '필팩터', 'TA_AVG', 'TA_MAX', 'TA_MIN']
# ====================================================================================================

# %%
### Modelling - Tree  
# Cycle Time 
cycle_model, cycle_importance = train_tree(cycle_train_dataset, cycle_test_dataset, target_col='cycle time')

# CT90 
ct_model, ct_importance = train_tree(ct_train_dataset, ct_test_dataset, target_col='Ct 90_결과')

# Scorch 
sc_model, sc_importance = train_tree(sc_train_dataset, sc_test_dataset, target_col='Scorch_결과')

# Vm 
vm_model, vm_importance = train_tree(vm_train_dataset, vm_test_dataset, target_col='Vm_결과')

# Hard 
hard_model, hard_importance = train_tree(hard_train_dataset, hard_test_dataset, target_col='경도_결과')
# Out:
# [I 2025-10-28 14:52:59,466] A new study created in memory with name: no-name-17daa593-8d0d-41ca-acaf-2ab28cc5dfb8
# 학습할 Tree Features: 22 | ['step1_Ram 압력', 'step2_Ram 압력', 'step3_Ram 압력', 'step1_Rotor speed', 'step2_Rotor speed', 'step3_Rotor speed', 'step1_mix온도', 'step2_mix온도', 'step3_mix온도', 'step1_전력량', 'step2_전력량', 'step3_전력량', 'step1_time', 'step2_time', 'step3_time', '필팩터', 'TA_AVG', 'TA_MAX', 'TA_MIN', 'Vm_feature', 'Scorch_feature', 'Cluster']
# 학습 Tree 데이터 수: 9851
#   0%|          | 0/10 [00:00<?, ?it/s]
# [I 2025-10-28 14:53:03,878] Trial 0 finished with value: 6.504513304872547 and parameters: {'n_estimators': 906, 'max_depth': 12, 'learning_rate': 0.0018319032473598927, 'subsample': 0.8972313942067422, 'gamma': 0.23951754876867948, 'reg_lambda': 0.005823906970602023}. Best is trial 0 with value: 6.504513304872547.
# [I 2025-10-28 14:53:06,681] Trial 1 finished with value: 7.265746764844512 and parameters: {'n_estimators': 831, 'max_depth': 10, 'learning_rate': 0.001842642984203602, 'subsample': 0.9808195847977546, 'gamma': 0.4649340790612695, 'reg_lambda': 0.15603380972432654}. Best is trial 0 with value: 6.504513304872547.
# [I 2025-10-28 14:53:09,089] Trial 2 finished with value: 3.234768476262436 and parameters: {'n_estimators': 1610, 'max_depth': 6, 'learning_rate': 0.009714361317866446, 'subsample': 0.7388471039809256, 'gamma': 0.21138444751307434, 'reg_lambda': 0.0014363629631061966}. Best is trial 2 with value: 3.234768476262436.
# [I 2025-10-28 14:53:09,502] Trial 3 finished with value: 3.3145113617900357 and parameters: {'n_estimators': 536, 'max_depth': 8, 'learning_rate': 0.1317566316412446, 'subsample': 0.8479017429285868, 'gamma': 0.3071755194738719, 'reg_lambda': 0.0023356101948062416}. Best is trial 2 with value: 3.234768476262436.
# [I 2025-10-28 14:53:11,575] Trial 4 finished with value: 3.630427432120755 and parameters: {'n_estimators': 2572, 'max_depth': 10, 'learning_rate': 0.028374037173189797, 'subsample': 0.8999369866370089, 'gamma': 0.36109147677647274, 'reg_lambda': 0.7831171387609925}. Best is trial 2 with value: 3.234768476262436.
# [I 2025-10-28 14:53:12,533] Trial 5 finished with value: 3.325365751032751 and parameters: {'n_estimators': 718, 'max_depth': 10, 'learning_rate': 0.0336080124267513, 'subsample': 0.7268767965349155, 'gamma': 0.3049855320033891, 'reg_lambda': 0.07459956170738982}. Best is trial 2 with value: 3.234768476262436.
# [I 2025-10-28 14:53:16,006] Trial 6 finished with value: 3.0920140595912917 and parameters: {'n_estimators': 2554, 'max_depth': 11, 'learning_rate': 0.022156089763149128, 'subsample': 0.7737951227477284, 'gamma': 0.03881523342391269, 'reg_lambda': 1.4081153157662456}. Best is trial 6 with value: 3.0920140595912917.
# [I 2025-10-28 14:53:19,937] Trial 7 finished with value: 2.957065507401879 and parameters: {'n_estimators': 2917, 'max_depth': 6, 'learning_rate': 0.003333893800914568, 'subsample': 0.944518334014548, 'gamma': 0.13820307825130607, 'reg_lambda': 2.675998445010623}. Best is trial 7 with value: 2.957065507401879.
# [I 2025-10-28 14:53:20,922] Trial 8 finished with value: 3.3317468280956533 and parameters: {'n_estimators': 1480, 'max_depth': 11, 'learning_rate': 0.12130115796456552, 'subsample': 0.7892560091397073, 'gamma': 0.19608636909359256, 'reg_lambda': 0.12525177757105385}. Best is trial 7 with value: 2.957065507401879.
# [I 2025-10-28 14:53:22,533] Trial 9 finished with value: 3.26134775607136 and parameters: {'n_estimators': 808, 'max_depth': 11, 'learning_rate': 0.018156573079058682, 'subsample': 0.7418103815380684, 'gamma': 0.300283688124564, 'reg_lambda': 0.0014504844696127154}. Best is trial 7 with value: 2.957065507401879.
# Tree 1차 모델 평가: R2: 0.995 | sMAPE: 0.406
# [I 2025-10-28 14:53:27,661] A new study created in memory with name: no-name-93719573-26a7-4b75-a3c3-ec31cb1a18ad
# ====================================================================================================
# Train Accuracy
# Train RMSE : 1.051
# Train R2   : 0.999
# Train SMAPE : 0.30
# ----------------------------------------------------------------------------------------------------
# Test Accuracy
# Test RMSE : 1.881
# Test R2   : 0.995
# Test SMAPE : 0.41
# ====================================================================================================
# 학습할 Tree Features: 22 | ['step1_Ram 압력', 'step2_Ram 압력', 'step3_Ram 압력', 'step1_Rotor speed', 'step2_Rotor speed', 'step3_Rotor speed', 'step1_mix온도', 'step2_mix온도', 'step3_mix온도', 'step1_전력량', 'step2_전력량', 'step3_전력량', 'step1_time', 'step2_time', 'step3_time', '필팩터', 'TA_AVG', 'TA_MAX', 'TA_MIN', 'Vm_feature', 'Scorch_feature', 'Cluster']
# 학습 Tree 데이터 수: 4713
#   0%|          | 0/10 [00:00<?, ?it/s]
# [I 2025-10-28 14:53:30,893] Trial 0 finished with value: 8.643612860568984 and parameters: {'n_estimators': 2823, 'max_depth': 9, 'learning_rate': 0.03171711019078264, 'subsample': 0.9722602054405416, 'gamma': 0.030179818644883227, 'reg_lambda': 0.05970101658911}. Best is trial 0 with value: 8.643612860568984.
# [I 2025-10-28 14:53:32,449] Trial 1 finished with value: 8.691795584244053 and parameters: {'n_estimators': 1953, 'max_depth': 8, 'learning_rate': 0.06769491979640406, 'subsample': 0.9138607482400858, 'gamma': 0.4311248789555215, 'reg_lambda': 0.022224709000396393}. Best is trial 0 with value: 8.643612860568984.
# [I 2025-10-28 14:53:33,237] Trial 2 finished with value: 9.295822765228227 and parameters: {'n_estimators': 815, 'max_depth': 6, 'learning_rate': 0.22436553221513283, 'subsample': 0.747972288639582, 'gamma': 0.19987983985291247, 'reg_lambda': 0.9918438283159485}. Best is trial 0 with value: 8.643612860568984.
# [I 2025-10-28 14:53:38,515] Trial 3 finished with value: 8.580554350040138 and parameters: {'n_estimators': 927, 'max_depth': 12, 'learning_rate': 0.005405533984762577, 'subsample': 0.8443211349635449, 'gamma': 0.17046423889493828, 'reg_lambda': 0.00177807838862008}. Best is trial 3 with value: 8.580554350040138.
# [I 2025-10-28 14:53:39,666] Trial 4 finished with value: 8.910470080244695 and parameters: {'n_estimators': 584, 'max_depth': 12, 'learning_rate': 0.07507753677088076, 'subsample': 0.7796253740482879, 'gamma': 0.09513961884605981, 'reg_lambda': 1.6425219359268926}. Best is trial 3 with value: 8.580554350040138.
# [I 2025-10-28 14:53:41,495] Trial 5 finished with value: 8.699573097104237 and parameters: {'n_estimators': 2097, 'max_depth': 8, 'learning_rate': 0.0776516776486734, 'subsample': 0.7216705162119521, 'gamma': 0.30371081118661714, 'reg_lambda': 0.2131542522412988}. Best is trial 3 with value: 8.580554350040138.
# [I 2025-10-28 14:53:43,300] Trial 6 finished with value: 8.679469033022853 and parameters: {'n_estimators': 1651, 'max_depth': 9, 'learning_rate': 0.048239622340626474, 'subsample': 0.9033131315701941, 'gamma': 0.10973028436162013, 'reg_lambda': 0.003593224439468844}. Best is trial 3 with value: 8.580554350040138.
# [I 2025-10-28 14:53:44,235] Trial 7 finished with value: 9.235600332560216 and parameters: {'n_estimators': 1472, 'max_depth': 11, 'learning_rate': 0.29739084791074655, 'subsample': 0.9015155209104583, 'gamma': 0.002982081261118319, 'reg_lambda': 0.0010826301963754246}. Best is trial 3 with value: 8.580554350040138.
# [I 2025-10-28 14:53:47,972] Trial 8 finished with value: 8.729615097084489 and parameters: {'n_estimators': 802, 'max_depth': 11, 'learning_rate': 0.0037997099930677557, 'subsample': 0.7931369788389706, 'gamma': 0.07671211502776687, 'reg_lambda': 0.0019068114595235544}. Best is trial 3 with value: 8.580554350040138.
# [I 2025-10-28 14:53:50,299] Trial 9 finished with value: 8.919352845055144 and parameters: {'n_estimators': 2602, 'max_depth': 9, 'learning_rate': 0.036880087999282066, 'subsample': 0.9996583419972409, 'gamma': 0.16247911430232753, 'reg_lambda': 0.001066706884234247}. Best is trial 3 with value: 8.580554350040138.
# Tree 1차 모델 평가: R2: 0.907 | sMAPE: 3.272
# [I 2025-10-28 14:53:56,250] A new study created in memory with name: no-name-f4ceae34-8c13-4bdc-b4e6-4991a769a67b
# ====================================================================================================
# Train Accuracy
# Train RMSE : 1.485
# Train R2   : 0.997
# Train SMAPE : 0.61
# ----------------------------------------------------------------------------------------------------
# Test Accuracy
# Test RMSE : 8.813
# Test R2   : 0.907
# Test SMAPE : 3.27
# ====================================================================================================
# 학습할 Tree Features: 22 | ['step1_Ram 압력', 'step2_Ram 압력', 'step3_Ram 압력', 'step1_Rotor speed', 'step2_Rotor speed', 'step3_Rotor speed', 'step1_mix온도', 'step2_mix온도', 'step3_mix온도', 'step1_전력량', 'step2_전력량', 'step3_전력량', 'step1_time', 'step2_time', 'step3_time', '필팩터', 'TA_AVG', 'TA_MAX', 'TA_MIN', 'Vm_feature', 'Scorch_feature', 'Cluster']
# 학습 Tree 데이터 수: 9851
#   0%|          | 0/10 [00:00<?, ?it/s]
# [I 2025-10-28 14:54:00,167] Trial 0 finished with value: 30.41821215160165 and parameters: {'n_estimators': 854, 'max_depth': 10, 'learning_rate': 0.0023162786846688387, 'subsample': 0.7064959368040824, 'gamma': 0.22736236087551964, 'reg_lambda': 0.0063736341383394575}. Best is trial 0 with value: 30.41821215160165.
# [I 2025-10-28 14:54:02,464] Trial 1 finished with value: 27.432475917786594 and parameters: {'n_estimators': 2881, 'max_depth': 12, 'learning_rate': 0.16552895794894748, 'subsample': 0.9361859313177867, 'gamma': 0.2567908055709541, 'reg_lambda': 0.7541023228276141}. Best is trial 1 with value: 27.432475917786594.
# [I 2025-10-28 14:54:05,462] Trial 2 finished with value: 25.579029715917336 and parameters: {'n_estimators': 1580, 'max_depth': 12, 'learning_rate': 0.07121746470976295, 'subsample': 0.7166511671866712, 'gamma': 0.06357578194518765, 'reg_lambda': 0.05118778604711032}. Best is trial 2 with value: 25.579029715917336.
# [I 2025-10-28 14:54:07,754] Trial 3 finished with value: 27.280531363630967 and parameters: {'n_estimators': 796, 'max_depth': 9, 'learning_rate': 0.03344769504515149, 'subsample': 0.9430756707487349, 'gamma': 0.4023284673621884, 'reg_lambda': 0.005241170812791368}. Best is trial 2 with value: 25.579029715917336.
# [I 2025-10-28 14:54:09,973] Trial 4 finished with value: 25.916052002583275 and parameters: {'n_estimators': 928, 'max_depth': 8, 'learning_rate': 0.016556694819772403, 'subsample': 0.8090113478615597, 'gamma': 0.1756728603353931, 'reg_lambda': 0.009453547344256054}. Best is trial 2 with value: 25.579029715917336.
# [I 2025-10-28 14:54:13,398] Trial 5 finished with value: 27.217531448425817 and parameters: {'n_estimators': 972, 'max_depth': 10, 'learning_rate': 0.03340423777304444, 'subsample': 0.9858654067696244, 'gamma': 0.24899847206505943, 'reg_lambda': 0.2719132146205053}. Best is trial 2 with value: 25.579029715917336.
# [I 2025-10-28 14:54:14,994] Trial 6 finished with value: 39.333350138297824 and parameters: {'n_estimators': 668, 'max_depth': 6, 'learning_rate': 0.0020315209462370117, 'subsample': 0.8518231729831771, 'gamma': 0.12063550546947455, 'reg_lambda': 0.04752862321217673}. Best is trial 2 with value: 25.579029715917336.
# [I 2025-10-28 14:54:18,077] Trial 7 finished with value: 26.883120264951874 and parameters: {'n_estimators': 2868, 'max_depth': 6, 'learning_rate': 0.2620797128523216, 'subsample': 0.8859244853204837, 'gamma': 0.45411672592405244, 'reg_lambda': 0.13141439884225417}. Best is trial 2 with value: 25.579029715917336.
# [I 2025-10-28 14:54:34,887] Trial 8 finished with value: 27.529405902911122 and parameters: {'n_estimators': 2574, 'max_depth': 12, 'learning_rate': 0.0011381660876255864, 'subsample': 0.9308100675322416, 'gamma': 0.35014940142352985, 'reg_lambda': 1.0134151120136017}. Best is trial 2 with value: 25.579029715917336.
# [I 2025-10-28 14:54:40,021] Trial 9 finished with value: 29.910018139632733 and parameters: {'n_estimators': 1533, 'max_depth': 9, 'learning_rate': 0.0014963242405062927, 'subsample': 0.8534804714703432, 'gamma': 0.3250420679784668, 'reg_lambda': 0.006448227841721241}. Best is trial 2 with value: 25.579029715917336.
# Tree 1차 모델 평가: R2: 0.923 | sMAPE: 4.18
# [I 2025-10-28 14:54:44,131] A new study created in memory with name: no-name-5d691b47-8cec-4068-8454-9e506df11a77
# ====================================================================================================
# Train Accuracy
# Train RMSE : 0.132
# Train R2   : 1.000
# Train SMAPE : 0.03
# ----------------------------------------------------------------------------------------------------
# Test Accuracy
# Test RMSE : 23.592
# Test R2   : 0.923
# Test SMAPE : 4.18
# ====================================================================================================
# 학습할 Tree Features: 22 | ['step1_Ram 압력', 'step2_Ram 압력', 'step3_Ram 압력', 'step1_Rotor speed', 'step2_Rotor speed', 'step3_Rotor speed', 'step1_mix온도', 'step2_mix온도', 'step3_mix온도', 'step1_전력량', 'step2_전력량', 'step3_전력량', 'step1_time', 'step2_time', 'step3_time', '필팩터', 'TA_AVG', 'TA_MAX', 'TA_MIN', 'Vm_feature', 'Scorch_feature', 'Cluster']
# 학습 Tree 데이터 수: 9851
#   0%|          | 0/10 [00:00<?, ?it/s]
# [I 2025-10-28 14:54:46,936] Trial 0 finished with value: 1.6419891388259333 and parameters: {'n_estimators': 2995, 'max_depth': 12, 'learning_rate': 0.055450449839650966, 'subsample': 0.9710179949143434, 'gamma': 0.12749219353390384, 'reg_lambda': 0.0023180487410336837}. Best is trial 0 with value: 1.6419891388259333.
# [I 2025-10-28 14:54:48,569] Trial 1 finished with value: 1.6465311765646817 and parameters: {'n_estimators': 2304, 'max_depth': 12, 'learning_rate': 0.19566606289459026, 'subsample': 0.823573175588382, 'gamma': 0.2388396258984935, 'reg_lambda': 0.019577374380002458}. Best is trial 0 with value: 1.6419891388259333.
# [I 2025-10-28 14:54:52,367] Trial 2 finished with value: 1.5099498568224188 and parameters: {'n_estimators': 2772, 'max_depth': 6, 'learning_rate': 0.02346150194319124, 'subsample': 0.7205228450773796, 'gamma': 0.35760226923896477, 'reg_lambda': 0.09843820192805187}. Best is trial 2 with value: 1.5099498568224188.
# [I 2025-10-28 14:54:54,961] Trial 3 finished with value: 1.5369918771579225 and parameters: {'n_estimators': 1636, 'max_depth': 8, 'learning_rate': 0.01818060403039995, 'subsample': 0.863626099870092, 'gamma': 0.42267294817234174, 'reg_lambda': 0.009807827216270154}. Best is trial 2 with value: 1.5099498568224188.
# [I 2025-10-28 14:54:55,382] Trial 4 finished with value: 1.639659595202593 and parameters: {'n_estimators': 419, 'max_depth': 6, 'learning_rate': 0.27627804882526147, 'subsample': 0.9974235952478052, 'gamma': 0.3153199205214692, 'reg_lambda': 0.00852412148320432}. Best is trial 2 with value: 1.5099498568224188.
# [I 2025-10-28 14:54:58,160] Trial 5 finished with value: 1.6702754415148937 and parameters: {'n_estimators': 885, 'max_depth': 9, 'learning_rate': 0.005127920676118975, 'subsample': 0.9427330424556075, 'gamma': 0.3150258365577781, 'reg_lambda': 0.514030145662866}. Best is trial 2 with value: 1.5099498568224188.
# [I 2025-10-28 14:55:00,690] Trial 6 finished with value: 1.5146137911199855 and parameters: {'n_estimators': 2369, 'max_depth': 7, 'learning_rate': 0.03466405182843399, 'subsample': 0.9778042372144005, 'gamma': 0.16000935118814963, 'reg_lambda': 0.26458929415206695}. Best is trial 2 with value: 1.5099498568224188.
# [I 2025-10-28 14:55:08,463] Trial 7 finished with value: 1.7990262451527863 and parameters: {'n_estimators': 1987, 'max_depth': 10, 'learning_rate': 0.0012471445656914845, 'subsample': 0.8641884091024955, 'gamma': 0.0334241321465904, 'reg_lambda': 0.005092580290898803}. Best is trial 2 with value: 1.5099498568224188.
# [I 2025-10-28 14:55:12,455] Trial 8 finished with value: 1.5863843761345107 and parameters: {'n_estimators': 2965, 'max_depth': 12, 'learning_rate': 0.0129874662455192, 'subsample': 0.9716185922605278, 'gamma': 0.46407774408696717, 'reg_lambda': 1.6254771475710557}. Best is trial 2 with value: 1.5099498568224188.
# [I 2025-10-28 14:55:14,849] Trial 9 finished with value: 1.9053182171954919 and parameters: {'n_estimators': 1274, 'max_depth': 7, 'learning_rate': 0.0026588202129045613, 'subsample': 0.7216950319247147, 'gamma': 0.21062127083211735, 'reg_lambda': 0.8940155480771721}. Best is trial 2 with value: 1.5099498568224188.
# Tree 1차 모델 평가: R2: 0.921 | sMAPE: 2.225
# [I 2025-10-28 14:55:19,314] A new study created in memory with name: no-name-67556d80-81ca-4080-9a8e-ed4766c9a77f
# ====================================================================================================
# Train Accuracy
# Train RMSE : 0.386
# Train R2   : 0.992
# Train SMAPE : 0.69
# ----------------------------------------------------------------------------------------------------
# Test Accuracy
# Test RMSE : 1.303
# Test R2   : 0.921
# Test SMAPE : 2.23
# ====================================================================================================
# 학습할 Tree Features: 22 | ['step1_Ram 압력', 'step2_Ram 압력', 'step3_Ram 압력', 'step1_Rotor speed', 'step2_Rotor speed', 'step3_Rotor speed', 'step1_mix온도', 'step2_mix온도', 'step3_mix온도', 'step1_전력량', 'step2_전력량', 'step3_전력량', 'step1_time', 'step2_time', 'step3_time', '필팩터', 'TA_AVG', 'TA_MAX', 'TA_MIN', 'Vm_feature', 'Scorch_feature', 'Cluster']
# 학습 Tree 데이터 수: 5849
#   0%|          | 0/10 [00:00<?, ?it/s]
# [I 2025-10-28 14:55:20,700] Trial 0 finished with value: 1.2454417688638786 and parameters: {'n_estimators': 1491, 'max_depth': 10, 'learning_rate': 0.031762798066707155, 'subsample': 0.864506782316383, 'gamma': 0.4502383636703329, 'reg_lambda': 0.06705250527273107}. Best is trial 0 with value: 1.2454417688638786.
# [I 2025-10-28 14:55:22,105] Trial 1 finished with value: 1.3140026923356534 and parameters: {'n_estimators': 1781, 'max_depth': 11, 'learning_rate': 0.27708267950226245, 'subsample': 0.7624621921884649, 'gamma': 0.00061654678403672, 'reg_lambda': 0.17886265131831894}. Best is trial 0 with value: 1.2454417688638786.
# [I 2025-10-28 14:55:25,527] Trial 2 finished with value: 1.2377610096290557 and parameters: {'n_estimators': 2528, 'max_depth': 12, 'learning_rate': 0.010466026119422312, 'subsample': 0.7730327146505469, 'gamma': 0.38915107257384823, 'reg_lambda': 0.0023425831271075962}. Best is trial 2 with value: 1.2377610096290557.
# [I 2025-10-28 14:55:35,735] Trial 3 finished with value: 1.2407538760389647 and parameters: {'n_estimators': 2563, 'max_depth': 12, 'learning_rate': 0.002446727181036036, 'subsample': 0.7567287320361303, 'gamma': 0.3995555977980677, 'reg_lambda': 0.052362728475883163}. Best is trial 2 with value: 1.2377610096290557.
# [I 2025-10-28 14:55:36,417] Trial 4 finished with value: 1.3055053694632657 and parameters: {'n_estimators': 1063, 'max_depth': 11, 'learning_rate': 0.22442489928394066, 'subsample': 0.7409503107728358, 'gamma': 0.1774148337713619, 'reg_lambda': 0.7142648436669398}. Best is trial 2 with value: 1.2377610096290557.
# [I 2025-10-28 14:55:38,336] Trial 5 finished with value: 1.2586903619660355 and parameters: {'n_estimators': 1849, 'max_depth': 7, 'learning_rate': 0.03845588977977087, 'subsample': 0.8352887986900361, 'gamma': 0.14698444010810363, 'reg_lambda': 1.5769976629905629}. Best is trial 2 with value: 1.2377610096290557.
# [I 2025-10-28 14:55:40,384] Trial 6 finished with value: 1.7611023085122297 and parameters: {'n_estimators': 528, 'max_depth': 11, 'learning_rate': 0.0013239834997149909, 'subsample': 0.9065041533463668, 'gamma': 0.03152576860237827, 'reg_lambda': 1.2246439968833411}. Best is trial 2 with value: 1.2377610096290557.
# [I 2025-10-28 14:55:41,028] Trial 7 finished with value: 1.2759750893153827 and parameters: {'n_estimators': 381, 'max_depth': 7, 'learning_rate': 0.041674750251993194, 'subsample': 0.9880321664472353, 'gamma': 0.09435204657435065, 'reg_lambda': 0.0015757177950167776}. Best is trial 2 with value: 1.2377610096290557.
# [I 2025-10-28 14:55:43,513] Trial 8 finished with value: 1.2485448241124744 and parameters: {'n_estimators': 2710, 'max_depth': 12, 'learning_rate': 0.019211957889000993, 'subsample': 0.8002564934096161, 'gamma': 0.3993409824093673, 'reg_lambda': 0.19510893112114888}. Best is trial 2 with value: 1.2377610096290557.
# [I 2025-10-28 14:55:46,752] Trial 9 finished with value: 1.3218221499636393 and parameters: {'n_estimators': 1055, 'max_depth': 9, 'learning_rate': 0.0018706762133554405, 'subsample': 0.9065651217374711, 'gamma': 0.171850974879039, 'reg_lambda': 0.010374560996525745}. Best is trial 2 with value: 1.2377610096290557.
# Tree 1차 모델 평가: R2: 0.814 | sMAPE: 1.186
# ====================================================================================================
# Train Accuracy
# Train RMSE : 0.313
# Train R2   : 0.986
# Train SMAPE : 0.33
# ----------------------------------------------------------------------------------------------------
# Test Accuracy
# Test RMSE : 1.183
# Test R2   : 0.814
# Test SMAPE : 1.19
# ====================================================================================================
